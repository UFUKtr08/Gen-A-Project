# %%
# Önce varsa mevcut mount'u kaldır
# !fusermount -u /content/drive

# Sonra yeniden bağla
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/Gen AI PROJECT/GenAI')
print("Çalışma dizini:", os.getcwd())
# Out:
# Çalışma dizini: /content/drive/MyDrive/Gen AI PROJECT/GenAI

# %%
import os
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import torchvision.transforms as transforms
from accelerate import Accelerator
from transformers import CLIPTextModel, CLIPTokenizer
from diffusers import AutoencoderKL, UNet2DConditionModel, DDPMScheduler
from peft import LoraConfig, get_peft_model
import pandas as pd

# --- Dataset tanımı ---
class CustomDataset(Dataset):
    def __init__(self, csv_file, transform=None):
        self.df = pd.read_csv(csv_file)
        self.df.iloc[:, 0] = self.df.iloc[:, 0].astype(str).str.replace('\\', '/', regex=False)
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        img_path = self.df.iloc[idx, 0]
        prompt = self.df.iloc[idx, 1]

        if not os.path.exists(img_path):
            raise FileNotFoundError(f"Dosya bulunamadı: {img_path}")

        image = Image.open(img_path).convert("RGB")
        if self.transform:
            image = self.transform(image)

        return image, prompt

# --- Görsel dönüşümleri ---
transform = transforms.Compose([
    transforms.Resize((512, 512)),
    transforms.ToTensor(),
    transforms.Normalize([0.5]*3, [0.5]*3),
])

# --- Paths ---
CSV_PATH = '/content/drive/MyDrive/Gen AI PROJECT/GenAI/photo_labels.csv'
dataset = CustomDataset(CSV_PATH, transform=transform)
loader = DataLoader(dataset, batch_size=4, shuffle=True, num_workers=2)

# --- Accelerator ve Cihaz ---
accelerator = Accelerator(mixed_precision="fp16")
device = accelerator.device

# --- Model bileşenleri ---
tokenizer = CLIPTokenizer.from_pretrained("openai/clip-vit-large-patch14")
text_encoder = CLIPTextModel.from_pretrained("openai/clip-vit-large-patch14")
vae = AutoencoderKL.from_pretrained("runwayml/stable-diffusion-v1-5", subfolder="vae")
unet = UNet2DConditionModel.from_pretrained("runwayml/stable-diffusion-v1-5", subfolder="unet")
noise_scheduler = DDPMScheduler.from_pretrained("runwayml/stable-diffusion-v1-5", subfolder="scheduler")

vae.to(device)

# --- LoRA Config ---
lora_config = LoraConfig(
    r=4,
    lora_alpha=16,
    target_modules=["to_q", "to_k", "to_v"],
    lora_dropout=0.05,
    bias="none"
)

unet_lora = get_peft_model(unet, lora_config)


# --- Optimizer ---
optimizer = torch.optim.AdamW(unet_lora.parameters(), lr=1e-4)

# --- Accelerator ile hazırlık ---
unet_lora, text_encoder, optimizer, loader = accelerator.prepare(
    unet_lora, text_encoder, optimizer, loader
)

# --- Eğitim döngüsü ---
max_train_steps = 1000
global_step = 0

for epoch in range(1000):
    for images, prompts in loader:
        tokens = tokenizer(
            prompts,
            padding="max_length",
            truncation=True,
            max_length=tokenizer.model_max_length,
            return_tensors="pt"
        ).to(device)

        text_embeds = text_encoder(**tokens).last_hidden_state

        with torch.no_grad():
            latents = vae.encode(images.to(device) * 2 - 1).latent_dist.sample()
            latents = latents * vae.config.scaling_factor

        noise = torch.randn_like(latents)
        timesteps = torch.randint(
            0,
            noise_scheduler.config.num_train_timesteps,
            (latents.shape[0],),
            device=device
        )

        noisy_latents = noise_scheduler.add_noise(latents, noise, timesteps)

        pred_noise = unet_lora(noisy_latents, timesteps, encoder_hidden_states=text_embeds).sample

        loss = F.mse_loss(pred_noise, noise)

        accelerator.backward(loss)
        optimizer.step()
        optimizer.zero_grad()

        global_step += 1
        print(f"Step {global_step} - Loss: {loss.item():.4f}")

        if global_step >= max_train_steps:
            break
    if global_step >= max_train_steps:
        break

# --- Model kaydetme ---
unet_lora.save_pretrained("sd15-lora-finetuned")
tokenizer.save_pretrained("sd15-lora-finetuned")
text_encoder.save_pretrained("sd15-lora-finetuned")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/905 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/961k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/389 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.22M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/4.52k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.71G [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/547 [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/335M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# scheduler_config.json:   0%|          | 0.00/308 [00:00<?, ?B/s]
# Step 1 - Loss: 0.1411
# Step 2 - Loss: 0.2144
# Step 3 - Loss: 0.0141
# Step 4 - Loss: 0.3218
# Step 5 - Loss: 0.0956
# Step 6 - Loss: 0.1469
# Step 7 - Loss: 0.2034
# Step 8 - Loss: 0.0907
# Step 9 - Loss: 0.1751
# Step 10 - Loss: 0.1982
# Step 11 - Loss: 0.1743
# Step 12 - Loss: 0.2970
# Step 13 - Loss: 0.0843
# Step 14 - Loss: 0.1147
# Step 15 - Loss: 0.1962
# Step 16 - Loss: 0.2349
# Step 17 - Loss: 0.2155
# Step 18 - Loss: 0.1889
# Step 19 - Loss: 0.0352
# Step 20 - Loss: 0.1965
# Step 21 - Loss: 0.3280
# Step 22 - Loss: 0.2571
# Step 23 - Loss: 0.0194
# Step 24 - Loss: 0.2423
# Step 25 - Loss: 0.2119
# Step 26 - Loss: 0.0909
# Step 27 - Loss: 0.2200
# Step 28 - Loss: 0.0187
# Step 29 - Loss: 0.2720
# Step 30 - Loss: 0.0655
# Step 31 - Loss: 0.0265
# Step 32 - Loss: 0.4666
# Step 33 - Loss: 0.1728
# Step 34 - Loss: 0.0772
# Step 35 - Loss: 0.1500
# Step 36 - Loss: 0.3809
# Step 37 - Loss: 0.1096
# Step 38 - Loss: 0.1971
# Step 39 - Loss: 0.0779
# Step 40 - Loss: 0.0344
# Step 41 - Loss: 0.0696
# Step 42 - Loss: 0.1188
# Step 43 - Loss: 0.2055
# Step 44 - Loss: 0.5057
# Step 45 - Loss: 0.1182
# Step 46 - Loss: 0.0881
# Step 47 - Loss: 0.2506
# Step 48 - Loss: 0.0982
# Step 49 - Loss: 0.0805
# Step 50 - Loss: 0.2087
# Step 51 - Loss: 0.1088
# Step 52 - Loss: 0.3880
# Step 53 - Loss: 0.1258
# Step 54 - Loss: 0.1132
# Step 55 - Loss: 0.1306
# Step 56 - Loss: 0.1812
# Step 57 - Loss: 0.0901
# Step 58 - Loss: 0.1309
# Step 59 - Loss: 0.0604
# Step 60 - Loss: 0.0781
# Step 61 - Loss: 0.2670
# Step 62 - Loss: 0.1428
# Step 63 - Loss: 0.1068
# Step 64 - Loss: 0.1042
# Step 65 - Loss: 0.2574
# Step 66 - Loss: 0.6710
# Step 67 - Loss: 0.0580
# Step 68 - Loss: 0.0683
# Step 69 - Loss: 0.2258
# Step 70 - Loss: 0.0703
# Step 71 - Loss: 0.2757
# Step 72 - Loss: 0.1081
# Step 73 - Loss: 0.1685
# Step 74 - Loss: 0.1617
# Step 75 - Loss: 0.2791
# Step 76 - Loss: 0.0581
# Step 77 - Loss: 0.2335
# Step 78 - Loss: 0.0476
# Step 79 - Loss: 0.0925
# Step 80 - Loss: 0.0360
# Step 81 - Loss: 0.0509
# Step 82 - Loss: 0.1084
# Step 83 - Loss: 0.1858
# Step 84 - Loss: 0.1996
# Step 85 - Loss: 0.1124
# Step 86 - Loss: 0.2767
# Step 87 - Loss: 0.1377
# Step 88 - Loss: 0.1314
# Step 89 - Loss: 0.2465
# Step 90 - Loss: 0.0469
# Step 91 - Loss: 0.2484
# Step 92 - Loss: 0.2924
# Step 93 - Loss: 0.1055
# Step 94 - Loss: 0.1673
# Step 95 - Loss: 0.2779
# Step 96 - Loss: 0.0742
# Step 97 - Loss: 0.1651
# Step 98 - Loss: 0.1301
# Step 99 - Loss: 0.3000
# Step 100 - Loss: 0.1006
# Step 101 - Loss: 0.0402
# Step 102 - Loss: 0.0515
# Step 103 - Loss: 0.2072
# Step 104 - Loss: 0.0622
# Step 105 - Loss: 0.2549
# Step 106 - Loss: 0.1631
# Step 107 - Loss: 0.0123
# Step 108 - Loss: 0.1356
# Step 109 - Loss: 0.1577
# Step 110 - Loss: 0.0128
# Step 111 - Loss: 0.2026
# Step 112 - Loss: 0.0869
# Step 113 - Loss: 0.2287
# Step 114 - Loss: 0.0542
# Step 115 - Loss: 0.1193
# Step 116 - Loss: 0.1556
# Step 117 - Loss: 0.0934
# Step 118 - Loss: 0.2013
# Step 119 - Loss: 0.2030
# Step 120 - Loss: 0.2947
# Step 121 - Loss: 0.1330
# Step 122 - Loss: 0.1115
# Step 123 - Loss: 0.1344
# Step 124 - Loss: 0.0471
# Step 125 - Loss: 0.1136
# Step 126 - Loss: 0.0764
# Step 127 - Loss: 0.0440
# Step 128 - Loss: 0.0936
# Step 129 - Loss: 0.2374
# Step 130 - Loss: 0.0470
# Step 131 - Loss: 0.0489
# Step 132 - Loss: 0.2346
# Step 133 - Loss: 0.0942
# Step 134 - Loss: 0.0090
# Step 135 - Loss: 0.0448
# Step 136 - Loss: 0.1583
# Step 137 - Loss: 0.1370
# Step 138 - Loss: 0.2654
# Step 139 - Loss: 0.0475
# Step 140 - Loss: 0.0327
# Step 141 - Loss: 0.0969
# Step 142 - Loss: 0.0153
# Step 143 - Loss: 0.1638
# Step 144 - Loss: 0.0294
# Step 145 - Loss: 0.2017
# Step 146 - Loss: 0.0982
# Step 147 - Loss: 0.1584
# Step 148 - Loss: 0.1989
# Step 149 - Loss: 0.1478
# Step 150 - Loss: 0.2008
# Step 151 - Loss: 0.0628
# Step 152 - Loss: 0.1544
# Step 153 - Loss: 0.0637
# Step 154 - Loss: 0.1811
# Step 155 - Loss: 0.1407
# Step 156 - Loss: 0.1159
# Step 157 - Loss: 0.3498
# Step 158 - Loss: 0.1501
# Step 159 - Loss: 0.2686
# Step 160 - Loss: 0.2134
# Step 161 - Loss: 0.1246
# Step 162 - Loss: 0.0606
# Step 163 - Loss: 0.0569
# Step 164 - Loss: 0.0696
# Step 165 - Loss: 0.2677
# Step 166 - Loss: 0.2084
# Step 167 - Loss: 0.2255
# Step 168 - Loss: 0.0708
# Step 169 - Loss: 0.0605
# Step 170 - Loss: 0.0642
# Step 171 - Loss: 0.0753
# Step 172 - Loss: 0.0872
# Step 173 - Loss: 0.0939
# Step 174 - Loss: 0.2457
# Step 175 - Loss: 0.1183
# Step 176 - Loss: 0.0298
# Step 177 - Loss: 0.2199
# Step 178 - Loss: 0.1199
# Step 179 - Loss: 0.1848
# Step 180 - Loss: 0.2870
# Step 181 - Loss: 0.1587
# Step 182 - Loss: 0.1067
# Step 183 - Loss: 0.0488
# Step 184 - Loss: 0.4182
# Step 185 - Loss: 0.0915
# Step 186 - Loss: 0.1154
# Step 187 - Loss: 0.5142
# Step 188 - Loss: 0.0660
# Step 189 - Loss: 0.0248
# Step 190 - Loss: 0.0688
# Step 191 - Loss: 0.1979
# Step 192 - Loss: 0.0459
# Step 193 - Loss: 0.2418
# Step 194 - Loss: 0.2801
# Step 195 - Loss: 0.1265
# Step 196 - Loss: 0.1607
# Step 197 - Loss: 0.0862
# Step 198 - Loss: 0.0428
# Step 199 - Loss: 0.2607
# Step 200 - Loss: 0.0754
# Step 201 - Loss: 0.0760
# Step 202 - Loss: 0.1161
# Step 203 - Loss: 0.0087
# Step 204 - Loss: 0.3780
# Step 205 - Loss: 0.0279
# Step 206 - Loss: 0.0482
# Step 207 - Loss: 0.2169
# Step 208 - Loss: 0.1207
# Step 209 - Loss: 0.2933
# Step 210 - Loss: 0.1921
# Step 211 - Loss: 0.1270
# Step 212 - Loss: 0.1492
# Step 213 - Loss: 0.0362
# Step 214 - Loss: 0.1947
# Step 215 - Loss: 0.0587
# Step 216 - Loss: 0.2342
# Step 217 - Loss: 0.1312
# Step 218 - Loss: 0.0683
# Step 219 - Loss: 0.1132
# Step 220 - Loss: 0.0287
# Step 221 - Loss: 0.0331
# Step 222 - Loss: 0.1102
# Step 223 - Loss: 0.0663
# Step 224 - Loss: 0.1679
# Step 225 - Loss: 0.2405
# Step 226 - Loss: 0.1446
# Step 227 - Loss: 0.1595
# Step 228 - Loss: 0.0333
# Step 229 - Loss: 0.1305
# Step 230 - Loss: 0.0901
# Step 231 - Loss: 0.0860
# Step 232 - Loss: 0.1860
# Step 233 - Loss: 0.1727
# Step 234 - Loss: 0.0464
# Step 235 - Loss: 0.0836
# Step 236 - Loss: 0.0365
# Step 237 - Loss: 0.1088
# Step 238 - Loss: 0.1096
# Step 239 - Loss: 0.0795
# Step 240 - Loss: 0.1442
# Step 241 - Loss: 0.0789
# Step 242 - Loss: 0.0862
# Step 243 - Loss: 0.0470
# Step 244 - Loss: 0.1933
# Step 245 - Loss: 0.1382
# Step 246 - Loss: 0.0915
# Step 247 - Loss: 0.0939
# Step 248 - Loss: 0.0537
# Step 249 - Loss: 0.1761
# Step 250 - Loss: 0.0923
# Step 251 - Loss: 0.1582
# Step 252 - Loss: 0.1100
# Step 253 - Loss: 0.1869
# Step 254 - Loss: 0.0483
# Step 255 - Loss: 0.0495
# Step 256 - Loss: 0.0789
# Step 257 - Loss: 0.0538
# Step 258 - Loss: 0.2520
# Step 259 - Loss: 0.0608
# Step 260 - Loss: 0.1994
# Step 261 - Loss: 0.1730
# Step 262 - Loss: 0.0637
# Step 263 - Loss: 0.2000
# Step 264 - Loss: 0.2453
# Step 265 - Loss: 0.1884
# Step 266 - Loss: 0.0440
# Step 267 - Loss: 0.0370
# Step 268 - Loss: 0.1595
# Step 269 - Loss: 0.1194
# Step 270 - Loss: 0.1082
# Step 271 - Loss: 0.0719
# Step 272 - Loss: 0.0568
# Step 273 - Loss: 0.1137
# Step 274 - Loss: 0.1608
# Step 275 - Loss: 0.0326
# Step 276 - Loss: 0.0568
# Step 277 - Loss: 0.3914
# Step 278 - Loss: 0.1177
# Step 279 - Loss: 0.1210
# Step 280 - Loss: 0.1048
# Step 281 - Loss: 0.0370
# Step 282 - Loss: 0.0942
# Step 283 - Loss: 0.0183
# Step 284 - Loss: 0.0876
# Step 285 - Loss: 0.0659
# Step 286 - Loss: 0.0410
# Step 287 - Loss: 0.1425
# Step 288 - Loss: 0.0813
# Step 289 - Loss: 0.1160
# Step 290 - Loss: 0.0296
# Step 291 - Loss: 0.1604
# Step 292 - Loss: 0.1607
# Step 293 - Loss: 0.0995
# Step 294 - Loss: 0.2170
# Step 295 - Loss: 0.0574
# Step 296 - Loss: 0.2027
# Step 297 - Loss: 0.0217
# Step 298 - Loss: 0.1641
# Step 299 - Loss: 0.0764
# Step 300 - Loss: 0.0743
# Step 301 - Loss: 0.0510
# Step 302 - Loss: 0.1451
# Step 303 - Loss: 0.1880
# Step 304 - Loss: 0.0562
# Step 305 - Loss: 0.2337
# Step 306 - Loss: 0.1702
# Step 307 - Loss: 0.1484
# Step 308 - Loss: 0.2206
# Step 309 - Loss: 0.1499
# Step 310 - Loss: 0.0912
# Step 311 - Loss: 0.0583
# Step 312 - Loss: 0.1605
# Step 313 - Loss: 0.1016
# Step 314 - Loss: 0.0152
# Step 315 - Loss: 0.0166
# Step 316 - Loss: 0.0710
# Step 317 - Loss: 0.0997
# Step 318 - Loss: 0.1444
# Step 319 - Loss: 0.1271
# Step 320 - Loss: 0.1504
# Step 321 - Loss: 0.2472
# Step 322 - Loss: 0.1749
# Step 323 - Loss: 0.2456
# Step 324 - Loss: 0.0601
# Step 325 - Loss: 0.1228
# Step 326 - Loss: 0.1142
# Step 327 - Loss: 0.0698
# Step 328 - Loss: 0.1439
# Step 329 - Loss: 0.0696
# Step 330 - Loss: 0.1342
# Step 331 - Loss: 0.0655
# Step 332 - Loss: 0.1946
# Step 333 - Loss: 0.1150
# Step 334 - Loss: 0.1052
# Step 335 - Loss: 0.0977
# Step 336 - Loss: 0.0189
# Step 337 - Loss: 0.0500
# Step 338 - Loss: 0.0925
# Step 339 - Loss: 0.0097
# Step 340 - Loss: 0.0765
# Step 341 - Loss: 0.2672
# Step 342 - Loss: 0.2172
# Step 343 - Loss: 0.0173
# Step 344 - Loss: 0.0935
# Step 345 - Loss: 0.0774
# Step 346 - Loss: 0.0916
# Step 347 - Loss: 0.1665
# Step 348 - Loss: 0.0478
# Step 349 - Loss: 0.0420
# Step 350 - Loss: 0.0648
# Step 351 - Loss: 0.0449
# Step 352 - Loss: 0.2888
# Step 353 - Loss: 0.0861
# Step 354 - Loss: 0.1331
# Step 355 - Loss: 0.1615
# Step 356 - Loss: 0.1549
# Step 357 - Loss: 0.1766
# Step 358 - Loss: 0.2156
# Step 359 - Loss: 0.0549
# Step 360 - Loss: 0.0246
# Step 361 - Loss: 0.2342
# Step 362 - Loss: 0.1500
# Step 363 - Loss: 0.1499
# Step 364 - Loss: 0.0274
# Step 365 - Loss: 0.0548
# Step 366 - Loss: 0.4113
# Step 367 - Loss: 0.1955
# Step 368 - Loss: 0.0882
# Step 369 - Loss: 0.4078
# Step 370 - Loss: 0.1389
# Step 371 - Loss: 0.0640
# Step 372 - Loss: 0.0910
# Step 373 - Loss: 0.2459
# Step 374 - Loss: 0.1730
# Step 375 - Loss: 0.1139
# Step 376 - Loss: 0.0118
# Step 377 - Loss: 0.2183
# Step 378 - Loss: 0.0660
# Step 379 - Loss: 0.2083
# Step 380 - Loss: 0.0484
# Step 381 - Loss: 0.1377
# Step 382 - Loss: 0.0309
# Step 383 - Loss: 0.0272
# Step 384 - Loss: 0.0441
# Step 385 - Loss: 0.1903
# Step 386 - Loss: 0.2854
# Step 387 - Loss: 0.1552
# Step 388 - Loss: 0.0597
# Step 389 - Loss: 0.1019
# Step 390 - Loss: 0.1234
# Step 391 - Loss: 0.0588
# Step 392 - Loss: 0.1033
# Step 393 - Loss: 0.0719
# Step 394 - Loss: 0.0626
# Step 395 - Loss: 0.3219
# Step 396 - Loss: 0.0686
# Step 397 - Loss: 0.0969
# Step 398 - Loss: 0.1156
# Step 399 - Loss: 0.1616
# Step 400 - Loss: 0.0424
# Step 401 - Loss: 0.2525
# Step 402 - Loss: 0.0255
# Step 403 - Loss: 0.0205
# Step 404 - Loss: 0.0369
# Step 405 - Loss: 0.1735
# Step 406 - Loss: 0.1685
# Step 407 - Loss: 0.1054
# Step 408 - Loss: 0.1170
# Step 409 - Loss: 0.0441
# Step 410 - Loss: 0.0951
# Step 411 - Loss: 0.0286
# Step 412 - Loss: 0.0905
# Step 413 - Loss: 0.0935
# Step 414 - Loss: 0.1937
# Step 415 - Loss: 0.0684
# Step 416 - Loss: 0.1379
# Step 417 - Loss: 0.1401
# Step 418 - Loss: 0.0968
# Step 419 - Loss: 0.2064
# Step 420 - Loss: 0.3101
# Step 421 - Loss: 0.0253
# Step 422 - Loss: 0.1197
# Step 423 - Loss: 0.1656
# Step 424 - Loss: 0.2142
# Step 425 - Loss: 0.0756
# Step 426 - Loss: 0.1349
# Step 427 - Loss: 0.0236
# Step 428 - Loss: 0.1466
# Step 429 - Loss: 0.2081
# Step 430 - Loss: 0.2991
# Step 431 - Loss: 0.0548
# Step 432 - Loss: 0.0476
# Step 433 - Loss: 0.1208
# Step 434 - Loss: 0.0795
# Step 435 - Loss: 0.0134
# Step 436 - Loss: 0.0802
# Step 437 - Loss: 0.1267
# Step 438 - Loss: 0.1104
# Step 439 - Loss: 0.0531
# Step 440 - Loss: 0.2211
# Step 441 - Loss: 0.0834
# Step 442 - Loss: 0.1625
# Step 443 - Loss: 0.0564
# Step 444 - Loss: 0.0601
# Step 445 - Loss: 0.0340
# Step 446 - Loss: 0.1318
# Step 447 - Loss: 0.1363
# Step 448 - Loss: 0.0492
# Step 449 - Loss: 0.1479
# Step 450 - Loss: 0.0316
# Step 451 - Loss: 0.0729
# Step 452 - Loss: 0.0856
# Step 453 - Loss: 0.1221
# Step 454 - Loss: 0.0461
# Step 455 - Loss: 0.1881
# Step 456 - Loss: 0.2774
# Step 457 - Loss: 0.1657
# Step 458 - Loss: 0.0811
# Step 459 - Loss: 0.1530
# Step 460 - Loss: 0.1737
# Step 461 - Loss: 0.2128
# Step 462 - Loss: 0.0305
# Step 463 - Loss: 0.1453
# Step 464 - Loss: 0.2682
# Step 465 - Loss: 0.0987
# Step 466 - Loss: 0.0991
# Step 467 - Loss: 0.1412
# Step 468 - Loss: 0.0280
# Step 469 - Loss: 0.0858
# Step 470 - Loss: 0.0590
# Step 471 - Loss: 0.0315
# Step 472 - Loss: 0.0405
# Step 473 - Loss: 0.0332
# Step 474 - Loss: 0.1567
# Step 475 - Loss: 0.0250
# Step 476 - Loss: 0.0216
# Step 477 - Loss: 0.0998
# Step 478 - Loss: 0.0834
# Step 479 - Loss: 0.1473
# Step 480 - Loss: 0.0802
# Step 481 - Loss: 0.0619
# Step 482 - Loss: 0.1452
# Step 483 - Loss: 0.0423
# Step 484 - Loss: 0.1570
# Step 485 - Loss: 0.1428
# Step 486 - Loss: 0.2301
# Step 487 - Loss: 0.1017
# Step 488 - Loss: 0.1510
# Step 489 - Loss: 0.0304
# Step 490 - Loss: 0.1662
# Step 491 - Loss: 0.1225
# Step 492 - Loss: 0.0317
# Step 493 - Loss: 0.0673
# Step 494 - Loss: 0.2562
# Step 495 - Loss: 0.1964
# Step 496 - Loss: 0.2080
# Step 497 - Loss: 0.1161
# Step 498 - Loss: 0.2148
# Step 499 - Loss: 0.0211
# Step 500 - Loss: 0.0808
# Step 501 - Loss: 0.1925
# Step 502 - Loss: 0.2047
# Step 503 - Loss: 0.1453
# Step 504 - Loss: 0.2085
# Step 505 - Loss: 0.2733
# Step 506 - Loss: 0.0404
# Step 507 - Loss: 0.3914
# Step 508 - Loss: 0.0541
# Step 509 - Loss: 0.1133
# Step 510 - Loss: 0.0645
# Step 511 - Loss: 0.0346
# Step 512 - Loss: 0.1294
# Step 513 - Loss: 0.1244
# Step 514 - Loss: 0.0896
# Step 515 - Loss: 0.0883
# Step 516 - Loss: 0.1260
# Step 517 - Loss: 0.2498
# Step 518 - Loss: 0.1573
# Step 519 - Loss: 0.2926
# Step 520 - Loss: 0.0695
# Step 521 - Loss: 0.1771
# Step 522 - Loss: 0.3001
# Step 523 - Loss: 0.0423
# Step 524 - Loss: 0.0102
# Step 525 - Loss: 0.0532
# Step 526 - Loss: 0.1669
# Step 527 - Loss: 0.1398
# Step 528 - Loss: 0.0634
# Step 529 - Loss: 0.0784
# Step 530 - Loss: 0.0580
# Step 531 - Loss: 0.1117
# Step 532 - Loss: 0.2150
# Step 533 - Loss: 0.1512
# Step 534 - Loss: 0.0825
# Step 535 - Loss: 0.0212
# Step 536 - Loss: 0.0278
# Step 537 - Loss: 0.0993
# Step 538 - Loss: 0.1985
# Step 539 - Loss: 0.0886
# Step 540 - Loss: 0.0995
# Step 541 - Loss: 0.1896
# Step 542 - Loss: 0.2208
# Step 543 - Loss: 0.0314
# Step 544 - Loss: 0.1627
# Step 545 - Loss: 0.0903
# Step 546 - Loss: 0.1188
# Step 547 - Loss: 0.0762
# Step 548 - Loss: 0.1862
# Step 549 - Loss: 0.2166
# Step 550 - Loss: 0.3204
# Step 551 - Loss: 0.1499
# Step 552 - Loss: 0.0688
# Step 553 - Loss: 0.2378
# Step 554 - Loss: 0.0380
# Step 555 - Loss: 0.1033
# Step 556 - Loss: 0.0245
# Step 557 - Loss: 0.1953
# Step 558 - Loss: 0.2738
# Step 559 - Loss: 0.0454
# Step 560 - Loss: 0.0691
# Step 561 - Loss: 0.0712
# Step 562 - Loss: 0.1216
# Step 563 - Loss: 0.0683
# Step 564 - Loss: 0.2904
# Step 565 - Loss: 0.3087
# Step 566 - Loss: 0.1198
# Step 567 - Loss: 0.1855
# Step 568 - Loss: 0.0903
# Step 569 - Loss: 0.1034
# Step 570 - Loss: 0.1324
# Step 571 - Loss: 0.0597
# Step 572 - Loss: 0.0943
# Step 573 - Loss: 0.3634
# Step 574 - Loss: 0.0173
# Step 575 - Loss: 0.1416
# Step 576 - Loss: 0.0556
# Step 577 - Loss: 0.1774
# Step 578 - Loss: 0.0346
# Step 579 - Loss: 0.1598
# Step 580 - Loss: 0.1005
# Step 581 - Loss: 0.0721
# Step 582 - Loss: 0.0627
# Step 583 - Loss: 0.0572
# Step 584 - Loss: 0.2033
# Step 585 - Loss: 0.1636
# Step 586 - Loss: 0.0401
# Step 587 - Loss: 0.1013
# Step 588 - Loss: 0.0913
# Step 589 - Loss: 0.1184
# Step 590 - Loss: 0.1749
# Step 591 - Loss: 0.3866
# Step 592 - Loss: 0.0231
# Step 593 - Loss: 0.1548
# Step 594 - Loss: 0.0160
# Step 595 - Loss: 0.0539
# Step 596 - Loss: 0.0328
# Step 597 - Loss: 0.1361
# Step 598 - Loss: 0.1802
# Step 599 - Loss: 0.3145
# Step 600 - Loss: 0.3664
# Step 601 - Loss: 0.1316
# Step 602 - Loss: 0.0849
# Step 603 - Loss: 0.1011
# Step 604 - Loss: 0.0700
# Step 605 - Loss: 0.1400
# Step 606 - Loss: 0.0492
# Step 607 - Loss: 0.0956
# Step 608 - Loss: 0.0471
# Step 609 - Loss: 0.0314
# Step 610 - Loss: 0.0429
# Step 611 - Loss: 0.3505
# Step 612 - Loss: 0.1689
# Step 613 - Loss: 0.1227
# Step 614 - Loss: 0.2118
# Step 615 - Loss: 0.0227
# Step 616 - Loss: 0.2656
# Step 617 - Loss: 0.0637
# Step 618 - Loss: 0.1211
# Step 619 - Loss: 0.2300
# Step 620 - Loss: 0.1702
# Step 621 - Loss: 0.3073
# Step 622 - Loss: 0.0590
# Step 623 - Loss: 0.0386
# Step 624 - Loss: 0.2793
# Step 625 - Loss: 0.1287
# Step 626 - Loss: 0.0407
# Step 627 - Loss: 0.1120
# Step 628 - Loss: 0.0301
# Step 629 - Loss: 0.1370
# Step 630 - Loss: 0.0935
# Step 631 - Loss: 0.2891
# Step 632 - Loss: 0.1989
# Step 633 - Loss: 0.1271
# Step 634 - Loss: 0.2822
# Step 635 - Loss: 0.1018
# Step 636 - Loss: 0.0704
# Step 637 - Loss: 0.0426
# Step 638 - Loss: 0.3188
# Step 639 - Loss: 0.1509
# Step 640 - Loss: 0.0927
# Step 641 - Loss: 0.0953
# Step 642 - Loss: 0.1531
# Step 643 - Loss: 0.0648
# Step 644 - Loss: 0.0487
# Step 645 - Loss: 0.1719
# Step 646 - Loss: 0.0962
# Step 647 - Loss: 0.0488
# Step 648 - Loss: 0.0100
# Step 649 - Loss: 0.1441
# Step 650 - Loss: 0.0926
# Step 651 - Loss: 0.0703
# Step 652 - Loss: 0.0835
# Step 653 - Loss: 0.2549
# Step 654 - Loss: 0.0380
# Step 655 - Loss: 0.0662
# Step 656 - Loss: 0.0657
# Step 657 - Loss: 0.1214
# Step 658 - Loss: 0.0832
# Step 659 - Loss: 0.0420
# Step 660 - Loss: 0.1617
# Step 661 - Loss: 0.0661
# Step 662 - Loss: 0.0893
# Step 663 - Loss: 0.1193
# Step 664 - Loss: 0.1714
# Step 665 - Loss: 0.0404
# Step 666 - Loss: 0.2124
# Step 667 - Loss: 0.1368
# Step 668 - Loss: 0.0766
# Step 669 - Loss: 0.0822
# Step 670 - Loss: 0.0719
# Step 671 - Loss: 0.0425
# Step 672 - Loss: 0.1237
# Step 673 - Loss: 0.0556
# Step 674 - Loss: 0.0286
# Step 675 - Loss: 0.1063
# Step 676 - Loss: 0.0800
# Step 677 - Loss: 0.2378
# Step 678 - Loss: 0.3531
# Step 679 - Loss: 0.1404
# Step 680 - Loss: 0.0377
# Step 681 - Loss: 0.3560
# Step 682 - Loss: 0.0217
# Step 683 - Loss: 0.0680
# Step 684 - Loss: 0.0750
# Step 685 - Loss: 0.0512
# Step 686 - Loss: 0.0393
# Step 687 - Loss: 0.0363
# Step 688 - Loss: 0.0887
# Step 689 - Loss: 0.0724
# Step 690 - Loss: 0.2075
# Step 691 - Loss: 0.3163
# Step 692 - Loss: 0.0092
# Step 693 - Loss: 0.0614
# Step 694 - Loss: 0.2899
# Step 695 - Loss: 0.0229
# Step 696 - Loss: 0.0712
# Step 697 - Loss: 0.2337
# Step 698 - Loss: 0.1769
# Step 699 - Loss: 0.0587
# Step 700 - Loss: 0.2078
# Step 701 - Loss: 0.0257
# Step 702 - Loss: 0.1021
# Step 703 - Loss: 0.1297
# Step 704 - Loss: 0.1748
# Step 705 - Loss: 0.1697
# Step 706 - Loss: 0.1356
# Step 707 - Loss: 0.2237
# Step 708 - Loss: 0.0933
# Step 709 - Loss: 0.0420
# Step 710 - Loss: 0.0239
# Step 711 - Loss: 0.0157
# Step 712 - Loss: 0.1999
# Step 713 - Loss: 0.2581
# Step 714 - Loss: 0.1497
# Step 715 - Loss: 0.1356
# Step 716 - Loss: 0.1136
# Step 717 - Loss: 0.3441
# Step 718 - Loss: 0.1198
# Step 719 - Loss: 0.0512
# Step 720 - Loss: 0.0518
# Step 721 - Loss: 0.0653
# Step 722 - Loss: 0.1385
# Step 723 - Loss: 0.0420
# Step 724 - Loss: 0.1565
# Step 725 - Loss: 0.0428
# Step 726 - Loss: 0.0849
# Step 727 - Loss: 0.3565
# Step 728 - Loss: 0.1566
# Step 729 - Loss: 0.0354
# Step 730 - Loss: 0.1705
# Step 731 - Loss: 0.0741
# Step 732 - Loss: 0.1362
# Step 733 - Loss: 0.1274
# Step 734 - Loss: 0.1131
# Step 735 - Loss: 0.0987
# Step 736 - Loss: 0.0186
# Step 737 - Loss: 0.0602
# Step 738 - Loss: 0.1448
# Step 739 - Loss: 0.1058
# Step 740 - Loss: 0.0496
# Step 741 - Loss: 0.1513
# Step 742 - Loss: 0.0154
# Step 743 - Loss: 0.0555
# Step 744 - Loss: 0.2027
# Step 745 - Loss: 0.2411
# Step 746 - Loss: 0.0161
# Step 747 - Loss: 0.0852
# Step 748 - Loss: 0.0490
# Step 749 - Loss: 0.1732
# Step 750 - Loss: 0.0800
# Step 751 - Loss: 0.2911
# Step 752 - Loss: 0.1001
# Step 753 - Loss: 0.1502
# Step 754 - Loss: 0.1415
# Step 755 - Loss: 0.2363
# Step 756 - Loss: 0.1150
# Step 757 - Loss: 0.1029
# Step 758 - Loss: 0.1804
# Step 759 - Loss: 0.1272
# Step 760 - Loss: 0.2727
# Step 761 - Loss: 0.2025
# Step 762 - Loss: 0.1860
# Step 763 - Loss: 0.1107
# Step 764 - Loss: 0.1249
# Step 765 - Loss: 0.2776
# Step 766 - Loss: 0.0965
# Step 767 - Loss: 0.1209
# Step 768 - Loss: 0.0667
# Step 769 - Loss: 0.0531
# Step 770 - Loss: 0.1827
# Step 771 - Loss: 0.2713
# Step 772 - Loss: 0.1353
# Step 773 - Loss: 0.1050
# Step 774 - Loss: 0.2193
# Step 775 - Loss: 0.0474
# Step 776 - Loss: 0.0530
# Step 777 - Loss: 0.0395
# Step 778 - Loss: 0.0337
# Step 779 - Loss: 0.0696
# Step 780 - Loss: 0.1899
# Step 781 - Loss: 0.1065
# Step 782 - Loss: 0.2030
# Step 783 - Loss: 0.0781
# Step 784 - Loss: 0.0945
# Step 785 - Loss: 0.1283
# Step 786 - Loss: 0.1865
# Step 787 - Loss: 0.0469
# Step 788 - Loss: 0.1442
# Step 789 - Loss: 0.0766
# Step 790 - Loss: 0.0904
# Step 791 - Loss: 0.0625
# Step 792 - Loss: 0.2394
# Step 793 - Loss: 0.0779
# Step 794 - Loss: 0.1118
# Step 795 - Loss: 0.0309
# Step 796 - Loss: 0.0311
# Step 797 - Loss: 0.2204
# Step 798 - Loss: 0.1436
# Step 799 - Loss: 0.0578
# Step 800 - Loss: 0.0269
# Step 801 - Loss: 0.1137
# Step 802 - Loss: 0.3562
# Step 803 - Loss: 0.1440
# Step 804 - Loss: 0.0854
# Step 805 - Loss: 0.1368
# Step 806 - Loss: 0.0735
# Step 807 - Loss: 0.1555
# Step 808 - Loss: 0.0494
# Step 809 - Loss: 0.0326
# Step 810 - Loss: 0.0968
# Step 811 - Loss: 0.2242
# Step 812 - Loss: 0.1257
# Step 813 - Loss: 0.0465
# Step 814 - Loss: 0.0309
# Step 815 - Loss: 0.0518
# Step 816 - Loss: 0.0325
# Step 817 - Loss: 0.0774
# Step 818 - Loss: 0.0352
# Step 819 - Loss: 0.1043
# Step 820 - Loss: 0.0578
# Step 821 - Loss: 0.0667
# Step 822 - Loss: 0.1767
# Step 823 - Loss: 0.1571
# Step 824 - Loss: 0.2628
# Step 825 - Loss: 0.0080
# Step 826 - Loss: 0.1638
# Step 827 - Loss: 0.1400
# Step 828 - Loss: 0.0890
# Step 829 - Loss: 0.1267
# Step 830 - Loss: 0.0673
# Step 831 - Loss: 0.2504
# Step 832 - Loss: 0.0856
# Step 833 - Loss: 0.0414
# Step 834 - Loss: 0.1167
# Step 835 - Loss: 0.1876
# Step 836 - Loss: 0.0167
# Step 837 - Loss: 0.1137
# Step 838 - Loss: 0.1153
# Step 839 - Loss: 0.0711
# Step 840 - Loss: 0.0801
# Step 841 - Loss: 0.0965
# Step 842 - Loss: 0.1228
# Step 843 - Loss: 0.1508
# Step 844 - Loss: 0.0713
# Step 845 - Loss: 0.1421
# Step 846 - Loss: 0.0106
# Step 847 - Loss: 0.3835
# Step 848 - Loss: 0.0999
# Step 849 - Loss: 0.0389
# Step 850 - Loss: 0.0806
# Step 851 - Loss: 0.0452
# Step 852 - Loss: 0.0551
# Step 853 - Loss: 0.0670
# Step 854 - Loss: 0.0469
# Step 855 - Loss: 0.1093
# Step 856 - Loss: 0.1002
# Step 857 - Loss: 0.0959
# Step 858 - Loss: 0.1484
# Step 859 - Loss: 0.1763
# Step 860 - Loss: 0.0720
# Step 861 - Loss: 0.0543
# Step 862 - Loss: 0.1138
# Step 863 - Loss: 0.0603
# Step 864 - Loss: 0.2118
# Step 865 - Loss: 0.0847
# Step 866 - Loss: 0.0462
# Step 867 - Loss: 0.0413
# Step 868 - Loss: 0.4345
# Step 869 - Loss: 0.1028
# Step 870 - Loss: 0.1387
# Step 871 - Loss: 0.0442
# Step 872 - Loss: 0.1155
# Step 873 - Loss: 0.1704
# Step 874 - Loss: 0.0702
# Step 875 - Loss: 0.0389
# Step 876 - Loss: 0.0788
# Step 877 - Loss: 0.2083
# Step 878 - Loss: 0.0434
# Step 879 - Loss: 0.2203
# Step 880 - Loss: 0.0460
# Step 881 - Loss: 0.1367
# Step 882 - Loss: 0.1710
# Step 883 - Loss: 0.0839
# Step 884 - Loss: 0.0690
# Step 885 - Loss: 0.1463
# Step 886 - Loss: 0.1760
# Step 887 - Loss: 0.0761
# Step 888 - Loss: 0.1008
# Step 889 - Loss: 0.1288
# Step 890 - Loss: 0.0894
# Step 891 - Loss: 0.0902
# Step 892 - Loss: 0.0168
# Step 893 - Loss: 0.0138
# Step 894 - Loss: 0.2126
# Step 895 - Loss: 0.2573
# Step 896 - Loss: 0.0475
# Step 897 - Loss: 0.0574
# Step 898 - Loss: 0.1277
# Step 899 - Loss: 0.2622
# Step 900 - Loss: 0.1054
# Step 901 - Loss: 0.1673
# Step 902 - Loss: 0.2332
# Step 903 - Loss: 0.1615
# Step 904 - Loss: 0.0598
# Step 905 - Loss: 0.0396
# Step 906 - Loss: 0.1875
# Step 907 - Loss: 0.0775
# Step 908 - Loss: 0.1461
# Step 909 - Loss: 0.1409
# Step 910 - Loss: 0.0957
# Step 911 - Loss: 0.1604
# Step 912 - Loss: 0.2807
# Step 913 - Loss: 0.1084
# Step 914 - Loss: 0.1364
# Step 915 - Loss: 0.1798
# Step 916 - Loss: 0.2123
# Step 917 - Loss: 0.2387
# Step 918 - Loss: 0.0865
# Step 919 - Loss: 0.0993
# Step 920 - Loss: 0.1798
# Step 921 - Loss: 0.1344
# Step 922 - Loss: 0.3217
# Step 923 - Loss: 0.1227
# Step 924 - Loss: 0.0387
# Step 925 - Loss: 0.0738
# Step 926 - Loss: 0.1364
# Step 927 - Loss: 0.0263
# Step 928 - Loss: 0.0482
# Step 929 - Loss: 0.1319
# Step 930 - Loss: 0.2690
# Step 931 - Loss: 0.0298
# Step 932 - Loss: 0.0636
# Step 933 - Loss: 0.0840
# Step 934 - Loss: 0.3616
# Step 935 - Loss: 0.0650
# Step 936 - Loss: 0.1334
# Step 937 - Loss: 0.1028
# Step 938 - Loss: 0.0568
# Step 939 - Loss: 0.0342
# Step 940 - Loss: 0.2100
# Step 941 - Loss: 0.2890
# Step 942 - Loss: 0.2387
# Step 943 - Loss: 0.0143
# Step 944 - Loss: 0.0150
# Step 945 - Loss: 0.2201
# Step 946 - Loss: 0.0876
# Step 947 - Loss: 0.0728
# Step 948 - Loss: 0.2328
# Step 949 - Loss: 0.2480
# Step 950 - Loss: 0.0848
# Step 951 - Loss: 0.1260
# Step 952 - Loss: 0.1277
# Step 953 - Loss: 0.1370
# Step 954 - Loss: 0.0653
# Step 955 - Loss: 0.1445
# Step 956 - Loss: 0.1735
# Step 957 - Loss: 0.0437
# Step 958 - Loss: 0.1011
# Step 959 - Loss: 0.1023
# Step 960 - Loss: 0.0850
# Step 961 - Loss: 0.1026
# Step 962 - Loss: 0.2148
# Step 963 - Loss: 0.1304
# Step 964 - Loss: 0.1277
# Step 965 - Loss: 0.0648
# Step 966 - Loss: 0.1905
# Step 967 - Loss: 0.1923
# Step 968 - Loss: 0.1019
# Step 969 - Loss: 0.0784
# Step 970 - Loss: 0.2422
# Step 971 - Loss: 0.1871
# Step 972 - Loss: 0.3728
# Step 973 - Loss: 0.1316
# Step 974 - Loss: 0.2546
# Step 975 - Loss: 0.0968
# Step 976 - Loss: 0.1425
# Step 977 - Loss: 0.1481
# Step 978 - Loss: 0.1073
# Step 979 - Loss: 0.2334
# Step 980 - Loss: 0.1308
# Step 981 - Loss: 0.0457
# Step 982 - Loss: 0.0123
# Step 983 - Loss: 0.3208
# Step 984 - Loss: 0.0970
# Step 985 - Loss: 0.0847
# Step 986 - Loss: 0.0404
# Step 987 - Loss: 0.2490
# Step 988 - Loss: 0.0278
# Step 989 - Loss: 0.2507
# Step 990 - Loss: 0.1748
# Step 991 - Loss: 0.1604
# Step 992 - Loss: 0.0193
# Step 993 - Loss: 0.1086
# Step 994 - Loss: 0.0860
# Step 995 - Loss: 0.1611
# Step 996 - Loss: 0.0753
# Step 997 - Loss: 0.0585
# Step 998 - Loss: 0.0711
# Step 999 - Loss: 0.2693
# Step 1000 - Loss: 0.0512

# %% [markdown]
# To create an output you can adjust prompt variable

# %%
import torch
from diffusers import (
    StableDiffusionPipeline,
    EulerAncestralDiscreteScheduler,
    AutoencoderKL,
    UNet2DConditionModel,
)
from transformers import CLIPTextModel, CLIPTokenizer
from peft import PeftModel

# Model and LoRA paths
model_id = "runwayml/stable-diffusion-v1-5"
lora_path = "./sd15-lora-finetuned"  # Replace with your LoRA weights path

# Device setup
device = "cuda" if torch.cuda.is_available() else "cpu"

# Load tokenizer and text encoder
tokenizer = CLIPTokenizer.from_pretrained("openai/clip-vit-large-patch14")
text_encoder = CLIPTextModel.from_pretrained("openai/clip-vit-large-patch14").to(device)

# Load VAE and UNet base models
vae = AutoencoderKL.from_pretrained(model_id, subfolder="vae").to(device)
unet = UNet2DConditionModel.from_pretrained(model_id, subfolder="unet")

# Load LoRA weights into UNet
unet_lora = PeftModel.from_pretrained(unet, lora_path).to(device)

# Load Euler Ancestral Scheduler
scheduler = EulerAncestralDiscreteScheduler.from_pretrained(model_id, subfolder="scheduler")

from transformers import CLIPFeatureExtractor

feature_extractor = CLIPFeatureExtractor.from_pretrained("openai/clip-vit-large-patch14")

pipe = StableDiffusionPipeline(
    vae=vae,
    unet=unet_lora,
    tokenizer=tokenizer,
    text_encoder=text_encoder,
    scheduler=scheduler,
    safety_checker=None,
    feature_extractor=feature_extractor,
)
pipe = pipe.to(device)

# Inference parameters
prompt = "A man smiling towards the sea "
num_inference_steps = 50
guidance_scale = 7.5

# Generate image
image = pipe(prompt, num_inference_steps=num_inference_steps, guidance_scale=guidance_scale,height=512, width=512).images[0]

# Save or display image
image.save("lora_output.png")
image.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/models/clip/feature_extraction_clip.py:28: FutureWarning: The class CLIPFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use CLIPImageProcessor instead.
#   warnings.warn(
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
#   0%|          | 0/50 [00:00<?, ?it/s]

# %% [markdown]
# after loading the model you can use it by just adjusting the proompt variable

# %%
# Inference parameters
prompt = "<fkylmz> side look smiling at beach"
num_inference_steps = 50
guidance_scale = 7.5

# Generate image
image = pipe(prompt, num_inference_steps=num_inference_steps, guidance_scale=guidance_scale,height=512, width=512).images[0]

# Save or display image
image.save("lora_output.png")
image.show()
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
# !ls sd15-lora-finetuned
# Out:
# adapter_config.json	   merges.txt	      special_tokens_map.json
# adapter_model.safetensors  model.safetensors  tokenizer_config.json
# config.json		   README.md	      vocab.json

# %%
# !pip install -q torch torchvision

# %%
# !pip install -q torch torchvision
